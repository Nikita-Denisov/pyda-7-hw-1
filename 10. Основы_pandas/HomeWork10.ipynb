# %% [markdown]
# **Задание 1**
# Скачайте с сайта https://grouplens.org/datasets/movielens/ датасет любого размера. Определите какому фильму было выставлено больше всего оценок 5.0.

# %%
import pandas as pd

ratings = pd.read_csv('C:/Users/User/Desktop/Python/Лекция 10. Основы Pandas/10._Основы_pandas/ml-25m/ml-25m/ratings.csv')
movies = pd.read_csv('C:/Users/User/Desktop/Python/Лекция 10. Основы Pandas/10._Основы_pandas/ml-25m/ml-25m/movies.csv')

# %%
ratings[ ratings.rating == 5.0 ]['movieId'].value_counts().head(3) #отфильтровывает "movieId" только с рейтингом 5.0 и выводит первые 3 с наибольшим количеством оценок 5.0
# Out:
# 318    39553
# 296    32169
# 356    25918
# Name: movieId, dtype: int64

# %%
movies[movies['movieId'] == 318] #ищем название фильма с ID "318"
# Out:
#      movieId                             title       genres
# 314      318  Shawshank Redemption, The (1994)  Crime|Drama

# %% [markdown]
# **Задание 2**
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %%
data = pd.read_csv('power.csv')
filtered_countries = data[ (data['country']=='Latvia') | (data['country']=='Lithuania') | (data['country']=='Estonia') ]
filtered_category = filtered_countries[ (filtered_countries['category']==4) | (filtered_countries['category']==12) | (filtered_countries['category']==21) ]
filtered_year = filtered_category[ (filtered_category['year']>=2005) & (filtered_category['year']<=2005) ]

# %%
filtered_year[ filtered_year.quantity > 0 ]['quantity'].sum()
# Out:
# 37164.0

# %% [markdown]
# **Задание 3**
# Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe.

# %%
pd.read_html('https://novosibirsk.bankiros.ru/currency')[1]
# Out:
#                                 Банк                            1 USD  \
#                                 Банк                          Покупка
# 0                           Сбербанк                            61.37
# 1                                NaN                              NaN
# 2             микрорайон Горский, 66                            61.37
# 3                ул. Гребенщикова, 8                            61.37
# 4               ул. Кошурникова, 8/1                            61.37
# ..                               ...                              ...
# 163  Показать все отделения на карте  Показать все отделения на карте
# 164                 ТрансКапиталБанк                            62.45
# 165                              NaN                              NaN
# 166      ул. Коммунистическая, д. 35                            62.45
# 167  Показать все отделения на карте  Показать все отделения на карте
#
# ...

# %%
pd.read_html('https://novosibirsk.bankiros.ru/currency')[0]
# Out:
#         0                                   1  \
# 0     NaN  Лучшие курсы в банках Новосибирска
# 1     NaN                             Покупка
# 2     usd                  62.91 БАНК «НЕЙВА»
# 3     eur                  69.31 БАНК «НЕЙВА»
# 4     gbp                    81.35 Альфа-Банк
# 5     byn                       26.4 Сбербанк
# 6  kzt100                      11.14 Сбербанк
# 7     cny                 8.92 Восточный Банк
# 8     chf                    64.56 Альфа-Банк
# 9  jpy100                       56.1 Банк ВТБ
#
#                                     2  \
# 0  Лучшие курсы в банках Новосибирска
# 1                             Продажа
# 2                      63.04 БКС Банк
# 3                      69.44 БКС Банк
# 4                    82.65 Альфа-Банк
# 5                       32.7 Сбербанк
# 6                      21.89 Сбербанк
# 7                         9.2 Пойдем!
# 8                    65.56 Альфа-Банк
# 9                    58.55 Почта Банк
#
# ...
